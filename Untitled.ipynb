# %%
# Importing Libraries for Data Analysis and Visualization
import pandas as pd
import numpy as np
import plotly as px
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
import warnings 
warnings.filterwarnings("ignore")

# %%
# Importing Encoding Tools for Feature Transformation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder

# %%
# # Loading and Displaying the Initial Rows of the Resale Flat Prices Dataset
# Reading the file 2015 to 2016
df_1 = pd.read_csv(r"C:/Users/SETHU/Music/Singapore  Resale Flat Prices Predicting/ResaleFlatPricesBasedonRegistrationDateFromJan2015toDec2016.csv")
df_1.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            60.0        Improved                 1986               70
# 1            68.0  New Generation                 1981               65
# 2            69.0  New Generation                 1980               64
# 3            68.0  New Generation                 1979               63
# 4            68.0  New Generation                 1980               64
#
#    resale_price
# 0      255000.0
# 1      275000.0
# 2      285000.0
# 3      290000.0
# 4      290000.0

# %%
# Loading and Displaying the Initial Rows of the Resale Flat Prices Dataset from 2017 Onwards
df_2 = pd.read_csv(r"C:/Users/SETHU/Music/Singapore  Resale Flat Prices Predicting/ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv")
df_2.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3  2017-01  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4  2017-01  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date     remaining_lease  \
# 0            44.0        Improved                 1979  61 years 04 months
# 1            67.0  New Generation                 1978  60 years 07 months
# 2            67.0  New Generation                 1980  62 years 05 months
# 3            68.0  New Generation                 1980   62 years 01 month
# 4            67.0  New Generation                 1980  62 years 05 months
#
#    resale_price
# 0      232000.0
# 1      250000.0
# 2      262000.0
# 3      265000.0
# 4      265000.0

# %%
# Concatenating Datasets from Different Time Periods and Resetting Index
df_3 = pd.concat([df_1,df_2], axis=0)
df_3.reset_index(drop=True,inplace=True)
df_3.tail()
# Out:
#           month    town  flat_type block     street_name storey_range  \
# 226471  2024-09  YISHUN     5 ROOM   298    YISHUN ST 20     10 TO 12
# 226472  2024-09  YISHUN     5 ROOM   636    YISHUN ST 61     04 TO 06
# 226473  2024-09  YISHUN  EXECUTIVE   792  YISHUN RING RD     07 TO 09
# 226474  2024-09  YISHUN  EXECUTIVE   606    YISHUN ST 61     01 TO 03
# 226475  2024-09  YISHUN  EXECUTIVE   824    YISHUN ST 81     01 TO 03
#
#         floor_area_sqm  flat_model  lease_commence_date     remaining_lease  \
# 226471           111.0    Improved                 2000  75 years 04 months
# 226472           121.0    Improved                 1987  62 years 03 months
# 226473           142.0   Apartment                 1987            62 years
# 226474           147.0   Apartment                 1987  62 years 03 months
# 226475           146.0  Maisonette                 1987  62 years 03 months
#
#         resale_price
# 226471      653888.0
# 226472      660000.0
# 226473      818888.0
# 226474      770000.0
# 226475      893888.0

# %%
# Displaying Dataset Summary and Structure
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226476 entries, 0 to 226475
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                226476 non-null  object
#  1   town                 226476 non-null  object
#  2   flat_type            226476 non-null  object
#  3   block                226476 non-null  object
#  4   street_name          226476 non-null  object
#  5   storey_range         226476 non-null  object
#  6   floor_area_sqm       226476 non-null  float64
#  7   flat_model           226476 non-null  object
#  8   lease_commence_date  226476 non-null  int64
#  9   remaining_lease      226476 non-null  object
#  10  resale_price         226476 non-null  float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 19.0+ MB

# %%
# Identifying Missing Values in the Dataset
df_3.isnull().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# remaining_lease        0
# resale_price           0
# dtype: int64

# %%
# Displaying the First Few Rows to Inspect Column Names
df_3.head(2)
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date remaining_lease  \
# 0            60.0        Improved                 1986              70
# 1            68.0  New Generation                 1981              65
#
#    resale_price
# 0      255000.0
# 1      275000.0

# %%
# Adding a New Column for Full Address
df_3["address"] = df_3["block"]+" "+df_3["street_name"]

# %%
# Dropping Unnecessary Columns: "block" and "street_name"
df_4 = df_3.drop(columns=["block","street_name"])

# %%
# Displaying the Updated DataFrame After Dropping Columns
df_4.head()
# Out:
#      month        town flat_type storey_range  floor_area_sqm      flat_model  \
# 0  2015-01  ANG MO KIO    3 ROOM     07 TO 09            60.0        Improved
# 1  2015-01  ANG MO KIO    3 ROOM     01 TO 03            68.0  New Generation
# 2  2015-01  ANG MO KIO    3 ROOM     01 TO 03            69.0  New Generation
# 3  2015-01  ANG MO KIO    3 ROOM     01 TO 03            68.0  New Generation
# 4  2015-01  ANG MO KIO    3 ROOM     07 TO 09            68.0  New Generation
#
#    lease_commence_date remaining_lease  resale_price                address
# 0                 1986              70      255000.0   174 ANG MO KIO AVE 4
# 1                 1981              65      275000.0  541 ANG MO KIO AVE 10
# 2                 1980              64      285000.0   163 ANG MO KIO AVE 4
# 3                 1979              63      290000.0  446 ANG MO KIO AVE 10
# 4                 1980              64      290000.0  557 ANG MO KIO AVE 10

# %%
# Converting "month" Column to DateTime Format
df_4["month"] = pd.to_datetime(df_4["month"], format="%Y-%m")

# %%
# Splitting "month" Column into Separate "year" and "month" Columns

df_4["year"] = df_4["month"].dt.year
df_4["month"] = df_4["month"].dt.month

# %%
# Displaying the First Few Rows After Splitting the "month" Column
df_4.head(3)
# Out:
#    month        town flat_type storey_range  floor_area_sqm      flat_model  \
# 0      1  ANG MO KIO    3 ROOM     07 TO 09            60.0        Improved
# 1      1  ANG MO KIO    3 ROOM     01 TO 03            68.0  New Generation
# 2      1  ANG MO KIO    3 ROOM     01 TO 03            69.0  New Generation
#
#    lease_commence_date remaining_lease  resale_price                address  \
# 0                 1986              70      255000.0   174 ANG MO KIO AVE 4
# 1                 1981              65      275000.0  541 ANG MO KIO AVE 10
# 2                 1980              64      285000.0   163 ANG MO KIO AVE 4
#
#    year
# 0  2015
# 1  2015
# 2  2015

# %%
# Displaying Unique Values in the "town" Column
df_4["town"].unique()
# Out:
# array(['ANG MO KIO', 'BEDOK', 'BISHAN', 'BUKIT BATOK', 'BUKIT MERAH',
#        'BUKIT PANJANG', 'BUKIT TIMAH', 'CENTRAL AREA', 'CHOA CHU KANG',
#        'CLEMENTI', 'GEYLANG', 'HOUGANG', 'JURONG EAST', 'JURONG WEST',
#        'KALLANG/WHAMPOA', 'MARINE PARADE', 'PASIR RIS', 'PUNGGOL',
#        'QUEENSTOWN', 'SEMBAWANG', 'SENGKANG', 'SERANGOON', 'TAMPINES',
#        'TOA PAYOH', 'WOODLANDS', 'YISHUN'], dtype=object)

# %%
# Counting the Number of Unique Values in the "town" Column
df_4["town"].nunique()
# Out:
# 26

# %%
# Displaying Unique Values in the "flat_model" Column
df_4["flat_model"].unique()
# Out:
# array(['Improved', 'New Generation', 'Model A', 'Standard', 'Simplified',
#        'Premium Apartment', 'Maisonette', 'Apartment', 'Model A2',
#        'Type S1', 'Type S2', 'Adjoined flat', 'Terrace', 'DBSS',
#        'Model A-Maisonette', 'Premium Maisonette', 'Multi Generation',
#        'Premium Apartment Loft', 'Improved-Maisonette', '2-room', '3Gen'],
#       dtype=object)

# %%
# Counting the Number of Unique Values in the "flat_model" Column
df_4["flat_model"].nunique()
# Out:
# 21

# %%
# Displaying Unique Values in the "flat_type" Column
df_4["flat_type"].unique()
# Out:
# array(['3 ROOM', '4 ROOM', '5 ROOM', '2 ROOM', 'EXECUTIVE', '1 ROOM',
#        'MULTI-GENERATION'], dtype=object)

# %%
# Counting the Number of Unique Values in the "flat_type" Column
df_4["flat_type"].nunique()
# Out:
# 7

# %%
# Applying Label Encoding to "town" and Ordinal Encoding to "flat_model" and "flat_type"

df_4["town"] = LabelEncoder().fit_transform(df_4["town"])

df_4["flat_model"] = OrdinalEncoder().fit_transform(df_4[["flat_model"]])

df_4["flat_type"] = OrdinalEncoder().fit_transform(df_4[["flat_type"]])

# %%
# Displaying Unique Encoded Values in the "town" Column
df_4["town"].unique()
# Out:
# array(['ANG MO KIO', 'BEDOK', 'BISHAN', 'BUKIT BATOK', 'BUKIT MERAH',
#        'BUKIT PANJANG', 'BUKIT TIMAH', 'CENTRAL AREA', 'CHOA CHU KANG',
#        'CLEMENTI', 'GEYLANG', 'HOUGANG', 'JURONG EAST', 'JURONG WEST',
#        'KALLANG/WHAMPOA', 'MARINE PARADE', 'PASIR RIS', 'PUNGGOL',
#        'QUEENSTOWN', 'SEMBAWANG', 'SENGKANG', 'SERANGOON', 'TAMPINES',
#        'TOA PAYOH', 'WOODLANDS', 'YISHUN'], dtype=object)

# %%
# Displaying Unique Encoded Values in the "flat_model" Column
df_4["flat_model"].unique()
# Out:
# array(['Improved', 'New Generation', 'Model A', 'Standard', 'Simplified',
#        'Premium Apartment', 'Maisonette', 'Apartment', 'Model A2',
#        'Type S1', 'Type S2', 'Adjoined flat', 'Terrace', 'DBSS',
#        'Model A-Maisonette', 'Premium Maisonette', 'Multi Generation',
#        'Premium Apartment Loft', 'Improved-Maisonette', '2-room', '3Gen'],
#       dtype=object)

# %%
# Displaying Unique Encoded Values in the "flat_type" Column
df_4["flat_type"].unique()
# Out:
# array(['3 ROOM', '4 ROOM', '5 ROOM', '2 ROOM', 'EXECUTIVE', '1 ROOM',
#        'MULTI-GENERATION'], dtype=object)

# %%
# Displaying the First Few Rows of the DataFrame After Encoding
df_4.head(2)
# Out:
#    month        town flat_type storey_range  floor_area_sqm      flat_model  \
# 0      1  ANG MO KIO    3 ROOM     07 TO 09            60.0        Improved
# 1      1  ANG MO KIO    3 ROOM     01 TO 03            68.0  New Generation
#
#    lease_commence_date remaining_lease  resale_price                address  \
# 0                 1986              70      255000.0   174 ANG MO KIO AVE 4
# 1                 1981              65      275000.0  541 ANG MO KIO AVE 10
#
#    year
# 0  2015
# 1  2015

# %%
# Splitting "storey_range" Column into "storey_start" and "storey_end" Columns
df_4[["storey_start", "storey_end"]] = df_4["storey_range"].str.split("TO", expand=True)

# %%
# Droping the "storey_range" column

df_4.drop(columns=["storey_range"], inplace=True)

# %%
df_4.head(3)
# Out:
#    month  town  flat_type  floor_area_sqm  flat_model  lease_commence_date  \
# 0      1     0        2.0            60.0         5.0                 1986
# 1      1     0        2.0            68.0        12.0                 1981
# 2      1     0        2.0            69.0        12.0                 1980
#
#   remaining_lease  resale_price                address  year storey_start  \
# 0              70      255000.0   174 ANG MO KIO AVE 4  2015          07
# 1              65      275000.0  541 ANG MO KIO AVE 10  2015          01
# 2              64      285000.0   163 ANG MO KIO AVE 4  2015          01
#
#   storey_end
# 0         09
# 1         03
# 2         03

# %%
df_4["address"].nunique()
# Out:
# 9601

# %%
# Address have 9591 unique values in the 218944, so i Encode it for the correlation checking
# I chooshing the "Label Encoder" for the "address" column

df_4["address"] = LabelEncoder().fit_transform(df_4["address"])

# %%
# Convert Data Type "storey_start" and "storey_end"

df_4["storey_start"] = df_4["storey_start"].astype(int)

df_4["storey_end"] = df_4["storey_end"].astype(int)

# %%
# Spliting the "remaining_lease" column in "remaining_lease_month" and "remaining_lease_year"

slice_values = []
for i in df_4["remaining_lease"].astype(str):
    j = i.replace("years","")
    k = j.replace("months","")
    l = k.replace("month","")
    m = l.strip()
    n = m.split("  ")
    slice_values.append(n)
    #print(n)

# %%
df_data = pd.DataFrame(slice_values,columns=["remaining_lease_year", "remaining_lease_month"])

# %%
# Data Type Convert "remaining_lease_year" and "remaining_lease_month"

df_data["remaining_lease_year"] = df_data["remaining_lease_year"].astype(int)

df_data["remaining_lease_month"] = df_data["remaining_lease_month"].fillna(0).astype(int)

# %%
# Droping the "remaining_lease" column

df_4.drop(columns=["remaining_lease"], inplace=True)

# %%
# Concadinating the DataFrames in "df_data" and "df_4"

df_5 = pd.concat([df_4,df_data], axis=1)

# %%
df_5.head(3)
# Out:
#    month  town  flat_type  floor_area_sqm  flat_model  lease_commence_date  \
# 0      1     0        2.0            60.0         5.0                 1986
# 1      1     0        2.0            68.0        12.0                 1981
# 2      1     0        2.0            69.0        12.0                 1980
#
#    resale_price  address  year  storey_start  storey_end  \
# 0      255000.0     1641  2015             7           9
# 1      275000.0     6606  2015             1           3
# 2      285000.0     1472  2015             1           3
#
#    remaining_lease_year  remaining_lease_month
# 0                    70                      0
# 1                    65                      0
# 2                    64                      0

# %%
df_5.columns
# Out:
# Index(['month', 'town', 'flat_type', 'floor_area_sqm', 'flat_model',
#        'lease_commence_date', 'resale_price', 'address', 'year',
#        'storey_start', 'storey_end', 'remaining_lease_year',
#        'remaining_lease_month'],
#       dtype='object')

# %%
# Rearange the column

df_6 = df_5[['year','month','town','flat_type', 'floor_area_sqm', 'flat_model','address',
             'storey_start', 'storey_end', 'remaining_lease_year','remaining_lease_month',
             'lease_commence_date', 'resale_price',]]

# %%
df_6.head(3)
# Out:
#    year  month  town  flat_type  floor_area_sqm  flat_model  address  \
# 0  2015      1     0        2.0            60.0         5.0     1641
# 1  2015      1     0        2.0            68.0        12.0     6606
# 2  2015      1     0        2.0            69.0        12.0     1472
#
#    storey_start  storey_end  remaining_lease_year  remaining_lease_month  \
# 0             7           9                    70                      0
# 1             1           3                    65                      0
# 2             1           3                    64                      0
#
#    lease_commence_date  resale_price
# 0                 1986      255000.0
# 1                 1981      275000.0
# 2                 1980      285000.0

# %%
df_7 = df_6.sort_values(by = ["year", "month"])
df_7.head(3)
# Out:
#    year  month  town  flat_type  floor_area_sqm  flat_model  address  \
# 0  2015      1     0        2.0            60.0         5.0     1641
# 1  2015      1     0        2.0            68.0        12.0     6606
# 2  2015      1     0        2.0            69.0        12.0     1472
#
#    storey_start  storey_end  remaining_lease_year  remaining_lease_month  \
# 0             7           9                    70                      0
# 1             1           3                    65                      0
# 2             1           3                    64                      0
#
#    lease_commence_date  resale_price
# 0                 1986      255000.0
# 1                 1981      275000.0
# 2                 1980      285000.0

# %%
# DataFrame save the "csv_file"

df_7.to_csv("Resale Flat Prices.csv", index= False)

# %%
df_final = pd.read_csv(r"C:/Users/SETHU/Music/Singapore  Resale Flat Prices Predicting/Resale Flat Prices.csv")
df_final.head()
# Out:
#    year  month  town  flat_type  floor_area_sqm  flat_model  address  \
# 0  2015      1     0        2.0            60.0         5.0     1641
# 1  2015      1     0        2.0            68.0        12.0     6606
# 2  2015      1     0        2.0            69.0        12.0     1472
# 3  2015      1     0        2.0            68.0        12.0     5441
# 4  2015      1     0        2.0            68.0        12.0     6760
#
#    storey_start  storey_end  remaining_lease_year  remaining_lease_month  \
# 0             7           9                    70                      0
# 1             1           3                    65                      0
# 2             1           3                    64                      0
# 3             1           3                    63                      0
# 4             7           9                    64                      0
#
#    lease_commence_date  resale_price
# 0                 1986      255000.0
# 1                 1981      275000.0
# 2                 1980      285000.0
# 3                 1979      290000.0
# 4                 1980      290000.0

# %%
# Checking the Correlation using heatmap

df_final_corr = df_final.corr()
plt.figure(figsize=(10,5))
sns.heatmap(df_final_corr, annot=True, cmap="Greens", fmt="0.2f")
plt.show()

# %%
# Checking the duplicate values
df_final.duplicated().sum()
# Out:
# 315

# %%
# Remove the duplicate values
df_final_1 = df_final.drop_duplicates()
df_final_1.reset_index(drop=True, inplace=True)

# %%
df_final_1.tail()
# Out:
#         year  month  town  flat_type  floor_area_sqm  flat_model  address  \
# 226156  2024      9    25        4.0           111.0         5.0     3530
# 226157  2024      9    25        4.0           121.0         5.0     7424
# 226158  2024      9    25        5.0           142.0         3.0     8673
# 226159  2024      9    25        5.0           147.0         3.0     7072
# 226160  2024      9    25        5.0           146.0         7.0     8884
#
#         storey_start  storey_end  remaining_lease_year  remaining_lease_month  \
# 226156            10          12                    75                      4
# 226157             4           6                    62                      3
# 226158             7           9                    62                      0
# 226159             1           3                    62                      3
# 226160             1           3                    62                      3
#
#         lease_commence_date  resale_price
# 226156                 2000      653888.0
# 226157                 1987      660000.0
# 226158                 1987      818888.0
# 226159                 1987      770000.0
# 226160                 1987      893888.0

# %%
# The "month" and "address" column does have very lowest correlation with other features
# So I drop the "month" and "address" columns

df_final_2 = df_final_1.drop(columns=["month","address"])

# %%
df_final_2.head(3)
# Out:
#    year  town  flat_type  floor_area_sqm  flat_model  storey_start  \
# 0  2015     0        2.0            60.0         5.0             7
# 1  2015     0        2.0            68.0        12.0             1
# 2  2015     0        2.0            69.0        12.0             1
#
#    storey_end  remaining_lease_year  remaining_lease_month  \
# 0           9                    70                      0
# 1           3                    65                      0
# 2           3                    64                      0
#
#    lease_commence_date  resale_price
# 0                 1986      255000.0
# 1                 1981      275000.0
# 2                 1980      285000.0

# %%
# detecting the skewed columns and outliers data find using plot 

def plot(df,column):
    # distplot
    plt.figure(figsize=(15,5))
    plt.subplot(1,3,1)
    sns.distplot(df[column])
    plt.title("Distplot for"+" "+column)

    # histogram plot
    plt.subplot(1,3,2)
    sns.histplot(df, x=column, kde=True, bins=30, color="salmon")
    plt.title("Histogram plot for"+" "+column)

    # boxplot
    plt.subplot(1,3,3)
    
    sns.boxplot(df, x=column)
    plt.title("Box plot for"+" "+column)

# %%
for i in df_final_2.columns:
    plot(df_final_2,i)

# %% [markdown]
# # Handling the skewness using (Log Transfermation)

# %% [raw]
# Log transformation is reduce skewness in a distribution and make it more symmetric. primarily used to convert a skewed distribution to a normal distribution.

# %%
df_final_3 = df_final_2.copy()

# %%
df_final_3.columns
# Out:
# Index(['year', 'town', 'flat_type', 'floor_area_sqm', 'flat_model',
#        'storey_start', 'storey_end', 'remaining_lease_year',
#        'remaining_lease_month', 'lease_commence_date', 'resale_price'],
#       dtype='object')

# %%
# The Skewness Columns
# 1. storey_start
# 2. storey_end
# 3. resale_price

# %%
df_final_3["storey_start"] = np.log(df_final_3["storey_start"])

df_final_3["storey_end"] = np.log(df_final_3["storey_end"])

df_final_3["resale_price"] = np.log(df_final_3["resale_price"])

# %%
skewed_columns = ["storey_start", "storey_end", "resale_price"]

for i in skewed_columns:
    plot(df_final_3,i)

# %% [markdown]
# # Outliers Handling - Outlier Removal in Dataset using IQR - Interquartile Range(IQR) Method Used

# %% [raw]
# An outlier is a single data point that goes far outside the average value of a group.

# %%
df_final_4 = df_final_3.copy()

# %%
df_final_4.columns
# Out:
# Index(['year', 'town', 'flat_type', 'floor_area_sqm', 'flat_model',
#        'storey_start', 'storey_end', 'remaining_lease_year',
#        'remaining_lease_month', 'lease_commence_date', 'resale_price'],
#       dtype='object')

# %%
# The Outlier Columns are

# 1. floor_area_sqm
# 2. storey_start_log
# 3. storey_end_log
# 4. resale_price_log

# %%
# The lower threshold is lower than the lowest input value 
# the upper threshold is greater than the highest input value

# %%
def outlier(df,column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.72)

    iqr= q3-q1

    upper_threshold = q3 + (1.5*iqr)
    lower_threshold = q1 - (1.5*iqr)

    #The clip() function is a numpy method that is used to limit the values in an array.
    df[column] = df[column].clip(lower_threshold, upper_threshold)

# %%
outlier_columns = ["floor_area_sqm","storey_start","storey_end","resale_price"]
for j in outlier_columns:
    outlier(df_final_4,j)

# %%
for k in outlier_columns:
    plot(df_final_4,k)

# %%
df_final_4.columns
# Out:
# Index(['year', 'town', 'flat_type', 'floor_area_sqm', 'flat_model',
#        'storey_start', 'storey_end', 'remaining_lease_year',
#        'remaining_lease_month', 'lease_commence_date', 'resale_price'],
#       dtype='object')

# %%
# Checking the correlation after the outlier cleard with proper data

plt.figure(figsize=(10,5))
sns.heatmap(df_final_4.corr(), annot=True, cmap="Greens", fmt="0.2f")
plt.show()

# %%
# DataFrame Save the "Csv_file"
df_final_4.to_csv("Resale Flat Prices With Proper Data", index=False)

# %%
df_final_5 = pd.read_csv(r"C:/Users/SETHU/Music/Singapore  Resale Flat Prices Predicting/Resale Flat Prices With Proper Data")
df_final_5.tail()
# Out:
#         year  town  flat_type  floor_area_sqm  flat_model  storey_start  \
# 226156  2024    25        4.0           111.0         5.0      2.302585
# 226157  2024    25        4.0           121.0         5.0      1.386294
# 226158  2024    25        5.0           142.0         3.0      1.945910
# 226159  2024    25        5.0           147.0         3.0      0.011858
# 226160  2024    25        5.0           146.0         7.0      0.011858
#
#         storey_end  remaining_lease_year  remaining_lease_month  \
# 226156    2.484907                    75                      4
# 226157    1.791759                    62                      3
# 226158    2.197225                    62                      0
# 226159    1.098612                    62                      3
# 226160    1.098612                    62                      3
#
#         lease_commence_date  resale_price
# 226156                 2000     13.390691
# 226157                 1987     13.399995
# 226158                 1987     13.615703
# 226159                 1987     13.554146
# 226160                 1987     13.703336

# %%
df_final_6 = df_final_5.copy()

# %%
df_final_6.describe().T
# Out:
#                           count         mean        std          min  \
# year                   226161.0  2019.769045   2.760507  2015.000000
# town                   226161.0    13.891520   7.955727     0.000000
# flat_type              226161.0     3.118712   0.919584     0.000000
# floor_area_sqm         226161.0    96.969582  23.751539    37.500000
# flat_model             226161.0     8.685980   3.641371     0.000000
# storey_start           226161.0     1.695779   0.921355     0.011858
# storey_end             226161.0     2.093593   0.601644     1.098612
# remaining_lease_year   226161.0    74.048651  13.546625    41.000000
# remaining_lease_month  226161.0     4.637422   3.776981     0.000000
# lease_commence_date    226161.0  1995.253152  13.752308  1966.000000
# resale_price           226161.0    13.049895   0.333117    12.151156
#
#                                25%          50%          75%          max
# year                   2017.000000  2020.000000  2022.000000  2024.000000
# town                      8.000000    14.000000    21.000000    25.000000
# flat_type                 2.000000     3.000000     4.000000     6.000000
# floor_area_sqm           81.000000    93.000000   112.000000   153.500000
# flat_model                5.000000     8.000000    12.000000    20.000000
# storey_start              1.386294     1.945910     2.302585     3.677021
# storey_end                1.791759     2.197225     2.484907     3.524627
# remaining_lease_year     63.000000    74.000000    86.000000    97.000000
# remaining_lease_month     1.000000     4.000000     8.000000    11.000000
# lease_commence_date    1985.000000  1995.000000  2005.000000  2020.000000
# resale_price             12.810389    13.038982    13.279367    13.909109

# %%
np.exp(13.877751)
# Out:
# 1064218.1967576945

# %%
# Checking how many datas are outliers based on "resale_price" (maximum value >), Filter method used.
df_final_1[df_final_1["resale_price"] > 1064218]
# Out:
#         year  month  town  flat_type  floor_area_sqm  flat_model  address  \
# 15290   2015     11     7        4.0           107.0        20.0     1948
# 18088   2016      1     7        4.0           108.0        20.0     1946
# 25982   2016      6     7        4.0           107.0        20.0     1948
# 29408   2016      8     7        4.0           105.0        20.0     1946
# 29991   2016      8    14        4.0           119.0         4.0     8696
# ...      ...    ...   ...        ...             ...         ...      ...
# 225982  2024      9    21        5.0           145.0         3.0     3890
# 225983  2024      9    21        5.0           149.0         7.0     5138
# 226046  2024      9    23        3.0            93.0         8.0      926
# 226053  2024      9    23        4.0           113.0         5.0      223
# 226054  2024      9    23        4.0           110.0         5.0     1189
#
#         storey_start  storey_end  remaining_lease_year  remaining_lease_month  \
# 15290             43          45                    94                      0
# 18088             28          30                    94                      0
# 25982             34          36                    93                      0
# 29408             31          33                    93                      0
# 29991             28          30                    93                      0
# ...              ...         ...                   ...                    ...
# 225982             1           3                    59                     10
# 225983            10          12                    63                      8
# 226046            37          39                    93                      0
# 226053             7           9                    95                      0
# 226054            34          36                    80                      5
#
#         lease_commence_date  resale_price
# 15290                  2011     1088000.0
# 18088                  2011     1068888.0
# 25982                  2011     1070000.0
# 29408                  2011     1070000.0
# 29991                  2011     1100000.0
# ...                     ...           ...
# 225982                 1985     1088888.0
# 225983                 1989     1100000.0
# 226046                 2018     1200888.0
# 226053                 2020     1200000.0
# 226054                 2006     1230000.0
#
# [1102 rows x 13 columns]

# %%
np.exp(12.165593)
# Out:
# 192065.7422588514

# %%
# Checking how many datas are outliers based on "resale_price" (minimum value <), Filter method used.

df_final_1[df_final_1["resale_price"] < 192065]
# Out:
#         year  month  town  flat_type  floor_area_sqm  flat_model  address  \
# 36014   2016     12     4        1.0            35.0        17.0     1963
# 36910   2016     12    23        1.0            40.0        17.0     6781
# 47067   2017      7     4        0.0            31.0         5.0     8093
# 48310   2017      7    24        1.0            45.0         5.0     1421
# 48852   2017      8     4        0.0            31.0         5.0     8093
# ...      ...    ...   ...        ...             ...         ...      ...
# 127297  2021      2     4        0.0            31.0         5.0     8093
# 129484  2021      3     4        0.0            31.0         5.0     8093
# 134203  2021      5     4        0.0            31.0         5.0     8093
# 197149  2023      8    22        2.0            67.0         8.0     6386
# 205712  2023     12    24        1.0            47.0         8.0     1762
#
#         storey_start  storey_end  remaining_lease_year  remaining_lease_month  \
# 36014              4           6                    53                      0
# 36910              1           3                    49                      0
# 47067              4           6                    56                      8
# 48310              7           9                    66                      4
# 48852              4           6                    56                      7
# ...              ...         ...                   ...                    ...
# 127297             4           6                    53                      1
# 129484             1           3                    53                      0
# 134203             1           3                    52                     10
# 197149             7           9                    91                      3
# 205712            28          30                    94                     11
#
#         lease_commence_date  resale_price
# 36014                  1971      192000.0
# 36910                  1967      190000.0
# 47067                  1975      175000.0
# 48310                  1984      188000.0
# 48852                  1975      190000.0
# ...                     ...           ...
# 127297                 1975      180000.0
# 129484                 1975      190000.0
# 134203                 1975      190000.0
# 197149                 2015      150000.0
# 205712                 2019      150000.0
#
# [202 rows x 13 columns]

# %% [markdown]
# # Model Selection for "Regression"

# %% [markdown]
# # Now we want to create the model for "resale_price" prediction

# %%
pip install xgboost
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting xgboost
#   Downloading xgboost-2.1.1-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\sethu\appdata\roaming\python\python312\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\sethu\appdata\roaming\python\python312\site-packages (from xgboost) (1.13.1)
# Downloading xgboost-2.1.1-py3-none-win_amd64.whl (124.9 MB)
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB 435.7 kB/s eta 0:04:47
#    ---------------------------------------- 0.1/124.9 MB 656.4 kB/s eta 0:03:11
#    ---------------------------------------- 0.3/124.9 MB 2.6 MB/s eta 0:00:48
#    ---------------------------------------- 0.6/124.9 MB 3.7 MB/s eta 0:00:34
#    ---------------------------------------- 0.9/124.9 MB 4.5 MB/s eta 0:00:28
#    ---------------------------------------- 1.2/124.9 MB 4.9 MB/s eta 0:00:26
#    ---------------------------------------- 1.5/124.9 MB 5.3 MB/s eta 0:00:24
#     --------------------------------------- 1.8/124.9 MB 5.6 MB/s eta 0:00:23
#     --------------------------------------- 2.2/124.9 MB 5.9 MB/s eta 0:00:21
#     --------------------------------------- 2.5/124.9 MB 6.1 MB/s eta 0:00:21
#     --------------------------------------- 2.9/124.9 MB 6.4 MB/s eta 0:00:19
#    - -------------------------------------- 3.3/124.9 MB 6.9 MB/s eta 0:00:18
#    - -------------------------------------- 3.7/124.9 MB 6.9 MB/s eta 0:00:18
#    - -------------------------------------- 4.0/124.9 MB 7.0 MB/s eta 0:00:18
#    - -------------------------------------- 4.2/124.9 MB 6.8 MB/s eta 0:00:18
#    - -------------------------------------- 4.5/124.9 MB 7.0 MB/s eta 0:00:18
#    - -------------------------------------- 4.9/124.9 MB 7.1 MB/s eta 0:00:17
#    - -------------------------------------- 5.3/124.9 MB 7.2 MB/s eta 0:00:17
124.9 MB 5.5 MB/s eta 0:00:16
#    ------------ --------------------------- 40.5/124.9 MB 5.5 MB/s eta 0:00:16
#    ------------- -------------------------- 40.7/124.9 MB 5.5 MB/s eta 0:00:16
#    ------------- -------------------------- 41.0/124.9 MB 5.6 MB/s eta 0:00:15
#    ------------- -------------------------- 41.1/124.9 MB 5.6 MB/s eta 0:00:15
#    ------------- -------------------------- 41.3/124.9 MB 5.7 MB/s eta 0:00:15
#    ------------- -------------------------- 41.4/124.9 MB 5.8 MB/s eta 0:00:15
#    ------------- -------------------------- 41.4/124.9 MB 5.8 MB/s eta 0:00:15
#    ------------- -------------------------- 41.6/124.9 MB 5.6 MB/s eta 0:00:16
#    ------------- -------------------------- 41.9/124.9 MB 5.6 MB/s eta 0:00:15
#    ------------- -------------------------- 42.1/124.9 MB 5.5 MB/s eta 0:00:15
#    ------------- -------------------------- 42.2/124.9 MB 5.6 MB/s eta 0:00:15
#    ------------- -------------------------- 42.4/124.9 MB 5.6 MB/s eta 0:00:15
#    ------------- -------------------------- 42.6/124.9 MB 5.6 MB/s eta 0:00:15
#    ------------- -------------------------- 42.9/124.9 MB 5.7 MB/s eta 0:00:15
#    ------------- -------------------------- 43.0/124.9 MB 5.7 MB/s eta 0:00:15
#    ------------- -------------------------- 43.1/124.9 MB 5.6 MB/s eta 0:00:15
#    ------------- -------------------------- 43.2/124.9 MB 5.5 MB/s eta 0:00:15
#    ------------- -------------------------- 43.4/124.9 MB 5.5 MB/s eta 0:00:15
#    ------------- -------------------------- 43.6/124.9 MB 5.5 MB/s eta 0:00:15
#    -------------- ------------------------- 43.8/124.9 MB 5.3 MB/s eta 0:00:16
#    -------------- ------------------------- 44.0/124.9 MB 5.2 MB/s eta 0:00:16
#    -------------- ------------------------- 44.3/124.9 MB 5.3 MB/s eta 0:00:16
#    -------------- ------------------------- 44.6/124.9 MB 5.2 MB/s eta 0:00:16
#    -------------- ------------------------- 44.6/124.9 MB 5.2 MB/s eta 0:00:16
#    -------------- ------------------------- 44.9/124.9 MB 5.2 MB/s eta 0:00:16
#    -------------- ------------------------- 45.0/124.9 MB 5.1 MB/s eta 0:00:16
#    -------------- ------------------------- 45.3/124.9 MB 5.1 MB/s eta 0:00:16
#    -------------- ------------------------- 45.8/124.9 MB 5.3 MB/s eta 0:00:15
#    -------------- ------------------------- 46.1/124.9 MB 5.2 MB/s eta 0:00:16
#    -------------- ------------------------- 46.1/124.9 MB 5.2 MB/s eta 0:00:16
#    -------------- ------------------------- 46.1/124.9 MB 5.2 MB/s eta 0:00:16
#    -------------- ------------------------- 46.1/124.9 MB 5.2 MB/s eta 0:00:16
#    -------------- ------------------------- 46.2/124.9 MB 4.9 MB/s eta 0:00:17
#    -------------- ------------------------- 46.3/124.9 MB 4.9 MB/s eta 0:00:17
#    -------------- ------------------------- 46.4/124.9 MB 4.9 MB/s eta 0:00:17
#    -------------- ------------------------- 46.6/124.9 MB 4.8 MB/s eta 0:00:17
#    --------------- ------------------------ 46.9/124.9 MB 4.7 MB/s eta 0:00:17
#    --------------- ------------------------ 47.0/124.9 MB 4.8 MB/s eta 0:00:17
#    --------------- ------------------------ 47.2/124.9 MB 4.8 MB/s eta 0:00:17
#    --------------- ------------------------ 47.3/124.9 MB 4.8 MB/s eta 0:00:17
#    --------------- ------------------------ 47.3/124.9 MB 4.8 MB/s eta 0:00:17
#    --------------- ------------------------ 47.4/124.9 MB 4.6 MB/s eta 0:00:17
#    --------------- ------------------------ 47.8/124.9 MB 4.8 MB/s eta 0:00:17
#    --------------- ------------------------ 48.1/124.9 MB 4.9 MB/s eta 0:00:16
#    --------------- ------------------------ 48.6/124.9 MB 4.8 MB/s eta 0:00:16
#    --------------- ------------------------ 48.8/124.9 MB 4.8 MB/s eta 0:00:16
#    --------------- ------------------------ 48.9/124.9 MB 4.9 MB/s eta 0:00:16
#    --------------- ------------------------ 48.9/124.9 MB 4.9 MB/s eta 0:00:16
#    --------------- ------------------------ 48.9/124.9 MB 4.9 MB/s eta 0:00:16
#    --------------- ------------------------ 48.9/124.9 MB 4.9 MB/s eta 0:00:16
#    --------------- ------------------------ 48.9/124.9 MB 4.9 MB/s eta 0:00:16
#    --------------- ------------------------ 48.9/124.9 MB 4.9 MB/s eta 0:00:16
#    --------------- ------------------------ 48.9/124.9 MB 4.9 MB/s eta 0:00:16
#    --------------- ------------------------ 48.9/124.9 MB 4.3 MB/s eta 0:00:18
#    --------------- ------------------------ 48.9/124.9 MB 4.2 MB/s eta 0:00:19
#    --------------- ------------------------ 49.0/124.9 MB 4.1 MB/s eta 0:00:19
#    --------------- ------------------------ 49.2/124.9 MB 4.1 MB/s eta 0:00:19
#    --------------- ------------------------ 49.4/124.9 MB 4.1 MB/s eta 0:00:19
#    --------------- ------------------------ 49.6/124.9 MB 4.1 MB/s eta 0:00:19
#    --------------- ------------------------ 49.7/124.9 MB 4.0 MB/s eta 0:00:19
#    ---------------- ----------------------- 50.1/124.9 MB 4.1 MB/s eta 0:00:19
#    ---------------- ----------------------- 50.3/124.9 MB 4.1 MB/s eta 0:00:19
#    ---------------- ----------------------- 50.5/124.9 MB 4.1 MB/s eta 0:00:19
#    ---------------- ----------------------- 50.7/124.9 MB 4.1 MB/s eta 0:00:19
#    ---------------- ----------------------- 51.0/124.9 MB 4.1 MB/s eta 0:00:19
#    ---------------- ----------------------- 51.1/124.9 MB 4.0 MB/s eta 0:00:19
#    ---------------- ----------------------- 51.5/124.9 MB 4.1 MB/s eta 0:00:18
#    ---------------- ----------------------- 51.8/124.9 MB 4.3 MB/s eta 0:00:18
#    ---------------- ----------------------- 52.1/124.9 MB 4.3 MB/s eta 0:00:17
#    ---------------- ----------------------- 52.2/124.9 MB 4.3 MB/s eta 0:00:18
#    ---------------- ----------------------- 52.2/124.9 MB 4.3 MB/s eta 0:00:18
#    ---------------- ----------------------- 52.2/124.9 MB 4.3 MB/s eta 0:00:18
#    ---------------- ----------------------- 52.2/124.9 MB 4.3 MB/s eta 0:00:18
#    ---------------- ----------------------- 52.2/124.9 MB 4.3 MB/s eta 0:00:18
#    ---------------- ----------------------- 52.2/124.9 MB 4.3 MB/s eta 0:00:18
#    ---------------- ----------------------- 52.2/124.9 MB 4.3 MB/s eta 0:00:18
#    ---------------- ----------------------- 52.2/124.9 MB 4.3 MB/s eta 0:00:18
#    ---------------- ----------------------- 52.3/124.9 MB 3.8 MB/s eta 0:00:20
#    ---------------- ----------------------- 52.3/124.9 MB 3.7 MB/s eta 0:00:20
#    ---------------- ----------------------- 52.4/124.9 MB 3.7 MB/s eta 0:00:20
#    ---------------- ----------------------- 52.5/124.9 MB 3.7 MB/s eta 0:00:20
#    ---------------- ----------------------- 52.6/124.9 MB 3.6 MB/s eta 0:00:20
#    ---------------- ----------------------- 52.7/124.9 MB 3.6 MB/s eta 0:00:20
#    ---------------- ----------------------- 52.9/124.9 MB 3.6 MB/s eta 0:00:20
#    ---------------- ----------------------- 53.0/124.9 MB 3.6 MB/s eta 0:00:20
#    ----------------- ---------------------- 53.1/124.9 MB 3.5 MB/s eta 0:00:21
#    ----------------- ---------------------- 53.5/124.9 MB 3.7 MB/s eta 0:00:20
#    ----------------- ---------------------- 53.7/124.9 MB 3.7 MB/s eta 0:00:20
#    ----------------- ---------------------- 53.8/124.9 MB 3.7 MB/s eta 0:00:20
#    ----------------- ---------------------- 54.0/124.9 MB 3.7 MB/s eta 0:00:20
#    ----------------- ---------------------- 54.5/124.9 MB 3.7 MB/s eta 0:00:20
#    ----------------- ---------------------- 54.9/124.9 MB 3.7 MB/s eta 0:00:19
#    ----------------- ---------------------- 55.1/124.9 MB 3.7 MB/s eta 0:00:19
#    ----------------- ---------------------- 55.4/124.9 MB 3.8 MB/s eta 0:00:19
#    ----------------- ---------------------- 55.4/124.9 MB 3.7 MB/s eta 0:00:19
#    ----------------- ---------------------- 55.6/124.9 MB 3.7 MB/s eta 0:00:19
#    ----------------- ---------------------- 55.6/124.9 MB 3.7 MB/s eta 0:00:19
#    ----------------- ---------------------- 55.9/124.9 MB 3.6 MB/s eta 0:00:20
#    ----------------- ---------------------- 55.9/124.9 MB 3.6 MB/s eta 0:00:20
#    ----------------- ---------------------- 56.2/124.9 MB 3.5 MB/s eta 0:00:20
#    ------------------ --------------------- 56.4/124.9 MB 3.7 MB/s eta 0:00:19
#    ------------------ --------------------- 56.4/124.9 MB 3.7 MB/s eta 0:00:19
#    ------------------ --------------------- 56.5/124.9 MB 3.7 MB/s eta 0:00:19
#    ------------------ ---------------------
9 MB 11.9 MB/s eta 0:00:03
#    ------------------------------ --------- 93.8/124.9 MB 11.9 MB/s eta 0:00:03
#    ------------------------------ --------- 94.3/124.9 MB 11.9 MB/s eta 0:00:03
#    ------------------------------ --------- 94.8/124.9 MB 12.1 MB/s eta 0:00:03
#    ------------------------------ --------- 95.3/124.9 MB 12.1 MB/s eta 0:00:03
#    ------------------------------ --------- 95.7/124.9 MB 11.9 MB/s eta 0:00:03
#    ------------------------------ --------- 96.2/124.9 MB 12.1 MB/s eta 0:00:03
#    ------------------------------ --------- 96.8/124.9 MB 12.1 MB/s eta 0:00:03
#    ------------------------------- -------- 97.2/124.9 MB 11.9 MB/s eta 0:00:03
#    ------------------------------- -------- 97.7/124.9 MB 11.9 MB/s eta 0:00:03
#    ------------------------------- -------- 98.2/124.9 MB 11.9 MB/s eta 0:00:03
#    ------------------------------- -------- 98.7/124.9 MB 12.1 MB/s eta 0:00:03
#    ------------------------------- -------- 99.3/124.9 MB 12.1 MB/s eta 0:00:03
#    ------------------------------- -------- 99.7/124.9 MB 12.1 MB/s eta 0:00:03
#    ------------------------------- ------- 100.2/124.9 MB 12.1 MB/s eta 0:00:03
#    ------------------------------- ------- 100.7/124.9 MB 12.1 MB/s eta 0:00:02
#    ------------------------------- ------- 101.2/124.9 MB 12.1 MB/s eta 0:00:02
#    ------------------------------- ------- 101.7/124.9 MB 12.3 MB/s eta 0:00:02
#    ------------------------------- ------- 102.1/124.9 MB 12.4 MB/s eta 0:00:02
#    -------------------------------- ------ 102.8/124.9 MB 12.1 MB/s eta 0:00:02
#    -------------------------------- ------ 103.0/124.9 MB 11.9 MB/s eta 0:00:02
#    -------------------------------- ------ 103.5/124.9 MB 12.1 MB/s eta 0:00:02
#    -------------------------------- ------ 104.0/124.9 MB 11.9 MB/s eta 0:00:02
#    -------------------------------- ------ 104.5/124.9 MB 12.1 MB/s eta 0:00:02
#    -------------------------------- ------ 105.0/124.9 MB 12.1 MB/s eta 0:00:02
#    -------------------------------- ------ 105.5/124.9 MB 11.9 MB/s eta 0:00:02
#    --------------------------------- ----- 105.9/124.9 MB 12.1 MB/s eta 0:00:02
#    --------------------------------- ----- 106.4/124.9 MB 11.9 MB/s eta 0:00:02
#    --------------------------------- ----- 106.8/124.9 MB 11.7 MB/s eta 0:00:02
#    --------------------------------- ----- 107.2/124.9 MB 11.9 MB/s eta 0:00:02
#    --------------------------------- ----- 107.8/124.9 MB 12.1 MB/s eta 0:00:02
#    --------------------------------- ----- 108.3/124.9 MB 11.9 MB/s eta 0:00:02
#    --------------------------------- ----- 108.7/124.9 MB 11.9 MB/s eta 0:00:02
#    ---------------------------------- ---- 109.0/124.9 MB 11.9 MB/s eta 0:00:02
#    ---------------------------------- ---- 109.4/124.9 MB 11.5 MB/s eta 0:00:02
#    ---------------------------------- ---- 109.9/124.9 MB 11.7 MB/s eta 0:00:02
#    ---------------------------------- ---- 110.3/124.9 MB 11.5 MB/s eta 0:00:02
#    ---------------------------------- ---- 111.0/124.9 MB 11.5 MB/s eta 0:00:02
#    ---------------------------------- ---- 111.4/124.9 MB 11.5 MB/s eta 0:00:02
#    ---------------------------------- ---- 111.8/124.9 MB 11.5 MB/s eta 0:00:02
#    ----------------------------------- --- 112.3/124.9 MB 11.5 MB/s eta 0:00:02
#    ----------------------------------- --- 112.8/124.9 MB 11.3 MB/s eta 0:00:02
#    ----------------------------------- --- 113.1/124.9 MB 11.5 MB/s eta 0:00:02
#    ----------------------------------- --- 113.6/124.9 MB 11.5 MB/s eta 0:00:01
#    ----------------------------------- --- 114.1/124.9 MB 11.5 MB/s eta 0:00:01
#    ----------------------------------- --- 114.6/124.9 MB 11.5 MB/s eta 0:00:01
#    ----------------------------------- --- 115.0/124.9 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------ -- 115.5/124.9 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------ -- 115.9/124.9 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------ -- 116.3/124.9 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------ -- 116.8/124.9 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------ -- 117.3/124.9 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------ -- 117.7/124.9 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------ -- 118.0/124.9 MB 10.9 MB/s eta 0:00:01
#    ------------------------------------ -- 118.4/124.9 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------ -- 118.5/124.9 MB 10.6 MB/s eta 0:00:01
#    ------------------------------------- - 118.7/124.9 MB 10.4 MB/s eta 0:00:01
#    ------------------------------------- - 119.0/124.9 MB 10.1 MB/s eta 0:00:01
#    -------------------------------------- - 119.2/124.9 MB 9.9 MB/s eta 0:00:01
#    -------------------------------------- - 119.4/124.9 MB 9.8 MB/s eta 0:00:01
#    -------------------------------------- - 119.6/124.9 MB 9.6 MB/s eta 0:00:01
#    -------------------------------------- - 119.7/124.9 MB 9.5 MB/s eta 0:00:01
#    -------------------------------------- - 119.8/124.9 MB 9.1 MB/s eta 0:00:01
#    -------------------------------------- - 120.0/124.9 MB 9.1 MB/s eta 0:00:01
#    -------------------------------------- - 120.2/124.9 MB 8.8 MB/s eta 0:00:01
#    -------------------------------------- - 120.6/124.9 MB 8.7 MB/s eta 0:00:01
#    -------------------------------------- - 121.0/124.9 MB 8.7 MB/s eta 0:00:01
#    -------------------------------------- - 121.5/124.9 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------  121.8/124.9 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  122.2/124.9 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------  122.5/124.9 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------  122.7/124.9 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------  122.9/124.9 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------  123.0/124.9 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------  123.0/124.9 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------  123.3/124.9 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------  123.7/124.9 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.9 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  124.3/124.9 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  124.7/124.9 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  124.9/124.9 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  124.9/124.9 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  124.9/124.9 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  124.9/124.9 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  124.9/124.9 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 124.9/124.9 MB 6.4 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-2.1.1
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\SETHU\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\SETHU\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\SETHU\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\SETHU\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\SETHU\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\SETHU\AppData\Roaming\Python\Python312\site-packages)

# %%
# imports the model

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
import pickle

# %%
# Check with High Accuracy Algorithm Model Selection

def select_model(df, algorithm):
    # Features and Target Set
    x = df.drop(columns=["resale_price"])
    y = df["resale_price"]

    # Train dataset and Test Dataset Splitting
    x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

    model = algorithm().fit(x_train, y_train)
    y_pred_train = model.predict(x_train)
    y_pred_test = model.predict(x_test)

    # Checking the Accuracy and Error
    train_mse = mean_squared_error(y_train, y_pred_train)
    train_rmse = np.sqrt(train_mse)
    train_mae = mean_absolute_error(y_train, y_pred_train)
    train_r2 = r2_score(y_train, y_pred_train)

    test_mse = mean_squared_error(y_test, y_pred_test)
    test_rmse = np.sqrt(test_mse)
    test_mae = mean_absolute_error(y_test, y_pred_test)
    test_r2 = r2_score(y_test, y_pred_test)

    metrics_train = {"Data": "Train Data",
                     "Name": algorithm.__name__,
                     "R2_score": train_r2,
                     "Mean_squared_error": train_mse,
                     "Root_mean_squared_error": train_rmse,
                     "Mean_absolute_error": train_mae,
                     }
    
    metrics_test = {"Data": "Test Data",
                    "Name": algorithm.__name__,
                    "R2_score": test_r2,
                    "Mean_squared_error": test_mse,
                    "Root_mean_squared_error": test_rmse,
                    "Mean_absolute_error": test_mae,
                    }
    
    print(metrics_train)
    print(metrics_test)
    print("")

# %%
select_model(df_final_5, LinearRegression)
select_model(df_final_5, DecisionTreeRegressor)
select_model(df_final_5, RandomForestRegressor)
select_model(df_final_5, AdaBoostRegressor)
select_model(df_final_5, ExtraTreesRegressor)
select_model(df_final_5, GradientBoostingRegressor)
select_model(df_final_5, XGBRegressor)
# Out:
# {'Data': 'Train Data', 'Name': 'LinearRegression', 'R2_score': 0.6803771280572023, 'Mean_squared_error': 0.03544348010690046, 'Root_mean_squared_error': 0.18826438884425398, 'Mean_absolute_error': 0.14735252154395417}
# {'Data': 'Test Data', 'Name': 'LinearRegression', 'R2_score': 0.6838287612096963, 'Mean_squared_error': 0.03517917920359388, 'Root_mean_squared_error': 0.18756113457641987, 'Mean_absolute_error': 0.14692366118523736}
#
# {'Data': 'Train Data', 'Name': 'DecisionTreeRegressor', 'R2_score': 0.9963087099799111, 'Mean_squared_error': 0.00040933292289307174, 'Root_mean_squared_error': 0.02023197773063898, 'Mean_absolute_error': 0.007161699547981506}
# {'Data': 'Test Data', 'Name': 'DecisionTreeRegressor', 'R2_score': 0.926455916752822, 'Mean_squared_error': 0.008182972283675802, 'Root_mean_squared_error': 0.09045978268642813, 'Mean_absolute_error': 0.0641519770676681}
#
# {'Data': 'Train Data', 'Name': 'RandomForestRegressor', 'R2_score': 0.9912799904897153, 'Mean_squared_error': 0.0009669754912441747, 'Root_mean_squared_error': 0.0310962295342084, 'Mean_absolute_error': 0.02212576946491544}
# {'Data': 'Test Data', 'Name': 'RandomForestRegressor', 'R2_score': 0.9561703194775895, 'Mean_squared_error': 0.004876762957420007, 'Root_mean_squared_error': 0.06983382387797482, 'Mean_absolute_error': 0.051254042765163196}
#
# {'Data': 'Train Data', 'Name': 'AdaBoostRegressor', 'R2_score': 0.6789109640811043, 'Mean_squared_error': 0.03560606532304727, 'Root_mean_squared_error': 0.1886956950305101, 'Mean_absolute_error': 0.1553357558234488}
# {'Data': 'Test Data', 'Name': 'AdaBoostRegressor', 'R2_score': 0.6839786261474002, 'Mean_squared_error': 0.035162504298185036, 'Root_mean_squared_error': 0.18751667738679947, 'Mean_absolute_error': 0.1541124972413999}
#
# {'Data': 'Train Data', 'Name': 'ExtraTreesRegressor', 'R2_score': 0.9963087099799111, 'Mean_squared_error': 0.00040933292289307174, 'Root_mean_squared_error': 0.02023197773063898, 'Mean_absolute_error': 0.007161699548039509}
# {'Data': 'Test Data', 'Name': 'ExtraTreesRegressor', 'R2_score': 0.9479141535788588, 'Mean_squared_error': 0.005795395344089054, 'Root_mean_squared_error': 0.07612749400899162, 'Mean_absolute_error': 0.0557280032089815}
#
# {'Data': 'Train Data', 'Name': 'GradientBoostingRegressor', 'R2_score': 0.8699055018848436, 'Mean_squared_error': 0.014426382342209125, 'Root_mean_squared_error': 0.12010987612269494, 'Mean_absolute_error': 0.09078140045441598}
# {'Data': 'Test Data', 'Name': 'GradientBoostingRegressor', 'R2_score': 0.8716490403146069, 'Mean_squared_error': 0.014281126357354712, 'Root_mean_squared_error': 0.11950366671092026, 'Mean_absolute_error': 0.09028986694420585}
#
# {'Data': 'Train Data', 'Name': 'XGBRegressor', 'R2_score': 0.9555401984531022, 'Mean_squared_error': 0.0049302169212916405, 'Root_mean_squared_error': 0.07021550342546609, 'Mean_absolute_error': 0.05361654772248324}
# {'Data': 'Test Data', 'Name': 'XGBRegressor', 'R2_score': 0.9535258845923296, 'Mean_squared_error': 0.005170999236079412, 'Root_mean_squared_error': 0.07190966024171865, 'Mean_absolute_error': 0.055005359211213564}

# %%
# RandomForestRegressor is good interpretability
# it will detect the unseen data for this datas and without overfitting, so i will select the algorithm

# Features and Target set
x = df_final_5.drop(columns=["resale_price"])
y = df_final_5["resale_price"]

# Train data and Test data Splitting
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

model_final = RandomForestRegressor().fit(x_train, y_train)
y_pred_test = model_final.predict(x_test)

test_mse = mean_squared_error(y_test, y_pred_test)
test_rmse = np.sqrt(test_mse)
test_mae = mean_absolute_error(y_test, y_pred_test)
test_r2 = r2_score(y_test, y_pred_test)

metrics_test = {"Data": "Test Data",
                "Name": RandomForestRegressor.__name__,
                "R2_score": test_r2,
                "Mean_squared_error": test_mse,
                "Root_mean_squared_error": test_rmse,
                "Mean_absolute_error": test_mae}

print(metrics_test)
print(y_pred_test)
# Out:
# {'Data': 'Test Data', 'Name': 'RandomForestRegressor', 'R2_score': 0.9561969828672808, 'Mean_squared_error': 0.004873796222786843, 'Root_mean_squared_error': 0.06981257925894761, 'Mean_absolute_error': 0.05119070304621845}
# [12.64196463 12.77147128 12.55592003 ... 12.73653467 13.40613378
#  12.69265679]

# %%
df_final_5.iloc[5000]
# Out:
# year                     2015.000000
# town                       22.000000
# flat_type                   2.000000
# floor_area_sqm             74.000000
# flat_model                  8.000000
# storey_start                1.945910
# storey_end                  2.197225
# remaining_lease_year       72.000000
# remaining_lease_month       0.000000
# lease_commence_date      1988.000000
# resale_price               12.730801
# Name: 5000, dtype: float64

# %%
np.exp(12.730801)
# Out:
# 337999.94103078236

# %%
user_data = np.array([[2015,22,2,74,8,1.94,2.19,72,0,1988]])
y_pred_1 = model_final.predict(user_data)
y_pred_1[0]
# Out:
# 12.740052275238476

# %%
np.exp(12.736671871152005)
# Out:
# 339990.1314935043

# %%
# Saving the Model Using Pickle Method
with open("Resale Flat Prices Model Final.pkl", "wb") as f:
    pickle.dump(model_final, f)

# %%
with open ("Resale Flat Prices Model Final.pkl", "rb") as f1:
    reg_model = pickle.load(f1)

# %%
df_final_5.iloc[10500]
# Out:
# year                     2015.000000
# town                        4.000000
# flat_type                   4.000000
# floor_area_sqm            115.000000
# flat_model                  5.000000
# storey_start                3.332205
# storey_end                  3.401197
# remaining_lease_year       89.000000
# remaining_lease_month       0.000000
# lease_commence_date      2005.000000
# resale_price               13.729953
# Name: 10500, dtype: float64

# %%
user_data_1 = np.array([[2015, 4, 4, 115, 5, 3.33, 3.40, 89, 0, 2005]])
y_pred_2 = reg_model.predict(user_data_1)
y_pred_2[0]
# Out:
# 13.72698243095063

# %%
np.exp(13.722771153848035)
# Out:
# 911430.9845139879
